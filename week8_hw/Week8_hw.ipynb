# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## generating a binomial distribution assuming a population size of 1000

# %%
s = np.random.binomial(2000, 0.4)
s
# Out:
# 835

# %%
i = 1
P = range(1, 2001)
p = []
s = 0.4
while i <= 2000:
    s = np.random.binomial(2000, s)/2000
    p.append(s)
    i = i+1

# %%
for i in range(0, 2000):
    if p[i] == 1 or p[i] == 0:
        print(i)
# Out:
# 1300
# 1301
# 1302
# 1303
# 1304
# 1305
# 1306
# 1307
# 1308
# 1309
# 1310
# 1311
# 1312
# 1313
# 1314
# 1315
# 1316
# 1317
# 1318
# 1319
# 1320
# 1321
# 1322
# 1323
# 1324
# 1325
# 1326
# 1327
# 1328
# 1329
# 1330
# 1331
# 1332
# 1333
# 1334
# 1335
# 1336
# 1337
# 1338
# 1339
# 1340
# 1341
# 1342
# 1343
# 1344
# 1345
# 1346
# 1347
# 1348
# 1349
# 1350
# 1351
# 1352
# 1353
# 1354
# 1355
# 1356
# 1357
# 1358
# 1359
# 1360
# 1361
# 1362
# 1363
# 1364
# 1365
# 1366
# 1367
# 1368
# 1369
# 1370
# 1371
# 1372
# 1373
# 1374
# 1375
# 1376
# 1377
# 1378
# 1379
# 1380
# 1381
# 1382
# 1383
# 1384
# 1385
# 1386
# 1387
# 1388
# 1389
# 1390
# 1391
# 1392
# 1393
# 1394
# 1395
# 1396
# 1397
# 1398
# 1399
# 1400
# 1401
# 1402
# 1403
# 1404
# 1405
# 1406
# 1407
# 1408
# 1409
# 1410
# 1411
# 1412
# 1413
# 1414
# 1415
# 1416
# 1417
# 1418
# 1419
# 1420
# 1421
# 1422
# 1423
# 1424
# 1425
# 1426
# 1427
# 1428
# 1429
# 1430
# 1431
# 1432
# 1433
# 1434
# 1435
# 1436
# 1437
# 1438
# 1439
# 1440
# 1441
# 1442
# 1443
# 1444
# 1445
# 1446
# 1447
# 1448
# 1449
# 1450
# 1451
# 1452
# 1453
# 1454
# 1455
# 1456
# 1457
# 1458
# 1459
# 1460
# 1461
# 1462
# 1463
# 1464
# 1465
# 1466
# 1467
# 1468
# 1469
# 1470
# 1471
# 1472
# 1473
# 1474
# 1475
# 1476
# 1477
# 1478
# 1479
# 1480
# 1481
# 1482
# 1483
# 1484
# 1485
# 1486
# 1487
# 1488
# 1489
# 1490
# 1491
# 1492
# 1493
# 1494
# 1495
# 1496
# 1497
# 1498
# 1499
# 1500
# 1501
# 1502
# 1503
# 1504
# 1505
# 1506
# 1507
# 1508
# 1509
# 1510
# 1511
# 1512
# 1513
# 1514
# 1515
# 1516
# 1517
# 1518
# 1519
# 1520
# 1521
# 1522
# 1523
# 1524
# 1525
# 1526
# 1527
# 1528
# 1529
# 1530
# 1531
# 1532
# 1533
# 1534
# 1535
# 1536
# 1537
# 1538
# 1539
# 1540
# 1541
# 1542
# 1543
# 1544
# 1545
# 1546
# 1547
# 1548
# 1549
# 1550
# 1551
# 1552
# 1553
# 1554
# 1555
# 1556
# 1557
# 1558
# 1559
# 1560
# 1561
# 1562
# 1563
# 1564
# 1565
# 1566
# 1567
# 1568
# 1569
# 1570
# 1571
# 1572
# 1573
# 1574
# 1575
# 1576
# 1577
# 1578
# 1579
# 1580
# 1581
# 1582
# 1583
# 1584
# 1585
# 1586
# 1587
# 1588
# 1589
# 1590
# 1591
# 1592
# 1593
# 1594
# 1595
# 1596
# 1597
# 1598
# 1599
# 1600
# 1601
# 1602
# 1603
# 1604
# 1605
# 1606
# 1607
# 1608
# 1609
# 1610
# 1611
# 1612
# 1613
# 1614
# 1615
# 1616
# 1617
# 1618
# 1619
# 1620
# 1621
# 1622
# 1623
# 1624
# 1625
# 1626
# 1627
# 1628
# 1629
# 1630
# 1631
# 1632
# 1633
# 1634
# 1635
# 1636
# 1637
# 1638
# 1639
# 1640
# 1641
# 1642
# 1643
# 1644
# 1645
# 1646
# 1647
# 1648
# 1649
# 1650
# 1651
# 1652
# 1653
# 1654
# 1655
# 1656
# 1657
# 1658
# 1659
# 1660
# 1661
# 1662
# 1663
# 1664
# 1665
# 1666
# 1667
# 1668
# 1669
# 1670
# 1671
# 1672
# 1673
# 1674
# 1675
# 1676
# 1677
# 1678
# 1679
# 1680
# 1681
# 1682
# 1683
# 1684
# 1685
# 1686
# 1687
# 1688
# 1689
# 1690
# 1691
# 1692
# 1693
# 1694
# 1695
# 1696
# 1697
# 1698
# 1699
# 1700
# 1701
# 1702
# 1703
# 1704
# 1705
# 1706
# 1707
# 1708
# 1709
# 1710
# 1711
# 1712
# 1713
# 1714
# 1715
# 1716
# 1717
# 1718
# 1719
# 1720
# 1721
# 1722
# 1723
# 1724
# 1725
# 1726
# 1727
# 1728
# 1729
# 1730
# 1731
# 1732
# 1733
# 1734
# 1735
# 1736
# 1737
# 1738
# 1739
# 1740
# 1741
# 1742
# 1743
# 1744
# 1745
# 1746
# 1747
# 1748
# 1749
# 1750
# 1751
# 1752
# 1753
# 1754
# 1755
# 1756
# 1757
# 1758
# 1759
# 1760
# 1761
# 1762
# 1763
# 1764
# 1765
# 1766
# 1767
# 1768
# 1769
# 1770
# 1771
# 1772
# 1773
# 1774
# 1775
# 1776
# 1777
# 1778
# 1779
# 1780
# 1781
# 1782
# 1783
# 1784
# 1785
# 1786
# 1787
# 1788
# 1789
# 1790
# 1791
# 1792
# 1793
# 1794
# 1795
# 1796
# 1797
# 1798
# 1799
# 1800
# 1801
# 1802
# 1803
# 1804
# 1805
# 1806
# 1807
# 1808
# 1809
# 1810
# 1811
# 1812
# 1813
# 1814
# 1815
# 1816
# 1817
# 1818
# 1819
# 1820
# 1821
# 1822
# 1823
# 1824
# 1825
# 1826
# 1827
# 1828
# 1829
# 1830
# 1831
# 1832
# 1833
# 1834
# 1835
# 1836
# 1837
# 1838
# 1839
# 1840
# 1841
# 1842
# 1843
# 1844
# 1845
# 1846
# 1847
# 1848
# 1849
# 1850
# 1851
# 1852
# 1853
# 1854
# 1855
# 1856
# 1857
# 1858
# 1859
# 1860
# 1861
# 1862
# 1863
# 1864
# 1865
# 1866
# 1867
# 1868
# 1869
# 1870
# 1871
# 1872
# 1873
# 1874
# 1875
# 1876
# 1877
# 1878
# 1879
# 1880
# 1881
# 1882
# 1883
# 1884
# 1885
# 1886
# 1887
# 1888
# 1889
# 1890
# 1891
# 1892
# 1893
# 1894
# 1895
# 1896
# 1897
# 1898
# 1899
# 1900
# 1901
# 1902
# 1903
# 1904
# 1905
# 1906
# 1907
# 1908
# 1909
# 1910
# 1911
# 1912
# 1913
# 1914
# 1915
# 1916
# 1917
# 1918
# 1919
# 1920
# 1921
# 1922
# 1923
# 1924
# 1925
# 1926
# 1927
# 1928
# 1929
# 1930
# 1931
# 1932
# 1933
# 1934
# 1935
# 1936
# 1937
# 1938
# 1939
# 1940
# 1941
# 1942
# 1943
# 1944
# 1945
# 1946
# 1947
# 1948
# 1949
# 1950
# 1951
# 1952
# 1953
# 1954
# 1955
# 1956
# 1957
# 1958
# 1959
# 1960
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999

# %%
plt.scatter(P, p, c = "green", s = 0.5)
plt.xlabel("generation")
plt.ylabel("allele frequency")
plt.title("Initial frequency = 0.4, population = 1000")
plt.show()

# %%
def generationtester(p, population):
    i = 1
    list = []
    s = p
    while True:
        s = np.random.binomial(2*population, s)/(2*population)
        if s == 0 or s == 1:
            return(i)
            break
        else:
            i = i+1

# %%
generationtester(0.5, 100)
# Out:
# 197

# %%
def simulation(p, population, n):
    g = []
    timer = 1
    while timer < n:
        g.append(generationtester(p, population))
        timer += 1
    return g

# %%
t = simulation(0.5, 100, 1000)

# %% [markdown]
# ## For a starting allele frequency of 0.5, and a population size of 100, produce a histogram with density showing time to fixation over (at least) 1000 trials.

# %%
plt.hist(t, color = "red", bins = 60)
plt.show()

# %%
N = []
n = 100
recorder = []
while n <= 10000000:
    recorder.append(generationtester(0.5, n))
    N.append(n)
    print(n)
    if n <= 1000000:
        n += 10000
    if n > 1000000:
        n += 1000000
# Out:
# 100
# 10100
# 20100
# 30100
# 40100
# 50100
# 60100
# 70100
# 80100
# 90100
# 100100
# 110100
# 120100
# 130100
# 140100
# 150100
# 160100
# 170100
# 180100
# 190100
# 200100
# 210100
# 220100
# 230100
# 240100
# 250100
# 260100
# 270100
# 280100
# 290100
# 300100
# 310100
# 320100
# 330100
# 340100
# 350100
# 360100
# 370100
# 380100
# 390100
# 400100
# 410100
# 420100
# 430100
# 440100
# 450100
# 460100
# 470100
# 480100
# 490100
# 500100
# 510100
# 520100
# 530100
# 540100
# 550100
# 560100
# 570100
# 580100
# 590100
# 600100
# 610100
# 620100
# 630100
# 640100
# 650100
# 660100
# 670100
# 680100
# 690100
# 700100
# 710100
# 720100
# 730100
# 740100
# 750100
# 760100
# 770100
# 780100
# 790100
# 800100
# 810100
# 820100
# 830100
# 840100
# 850100
# 860100
# 870100
# 880100
# 890100
# 900100
# 910100
# 920100
# 930100
# 940100
# 950100
# 960100
# 970100
# 980100
# 990100
# 2000100
# 3000100
# 4000100
# 5000100
# 6000100
# 7000100
# 8000100
# 9000100

# %% [markdown]
# ## For a starting allele frequency of 0.5, vary the population size and produce a plot that shows fixation time vs (N). A reasonable range of population sizes might be 100 to 10 million.

# %%
plt.figure(figsize = (20, 20))
plt.scatter(N, recorder, c = "blue", s = 20)
plt.xlabel("Population size", size = 20)
plt.ylabel("Fixation time", size = 20)
plt.title("Initial allele frequency: 0.5", size = 30)
plt.show()

# %% [markdown]
# ## Simulate the time to fixation under a range of different starting allele frequencies. Produce a plot showing starting allele frequency vs. number of generations to fix. Do (at least) 100 simulations for each and include the variability in your plot.

# %%
T = []
t = 0.5
recorder = []
while t < 1:
    recorder.append(simulation(t, 100, 100))
    T.append(t)
    print(t)
    t += 0.02
# Out:
# 0.5
# 0.52
# 0.54
# 0.56
# 0.5800000000000001
# 0.6000000000000001
# 0.6200000000000001
# 0.6400000000000001
# 0.6600000000000001
# 0.6800000000000002
# 0.7000000000000002
# 0.7200000000000002
# 0.7400000000000002
# 0.7600000000000002
# 0.7800000000000002
# 0.8000000000000003
# 0.8200000000000003
# 0.8400000000000003
# 0.8600000000000003
# 0.8800000000000003
# 0.9000000000000004
# 0.9200000000000004
# 0.9400000000000004
# 0.9600000000000004
# 0.9800000000000004

# %%
T
# Out:
# [0.5,
#  0.52,
#  0.54,
#  0.56,
#  0.5800000000000001,
#  0.6000000000000001,
#  0.6200000000000001,
#  0.6400000000000001,
#  0.6600000000000001,
#  0.6800000000000002,
#  0.7000000000000002,
#  0.7200000000000002,
#  0.7400000000000002,
#  0.7600000000000002,
#  0.7800000000000002,
#  0.8000000000000003,
#  0.8200000000000003,
#  0.8400000000000003,
#  0.8600000000000003,
#  0.8800000000000003,
#  0.9000000000000004,
#  0.9200000000000004,
#  0.9400000000000004,
#  0.9600000000000004,
#  0.9800000000000004]

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (20, 20))
ax = sns.boxplot(data = recorder, showfliers = False)
ax.set_xlabel("allele frequency", size = 20)
ax.set_ylabel("time to reach fixation", size = 20)
ax.set_title("Fixation Time vs Allele Frequency (Population = 100)", size = 20)
for i, d in enumerate(recorder):
    y = recorder[i]
    x = np.random.normal(i, 0.04, len(y))
    plt.scatter(x, y, s = 8)
ax.set_xticklabels(T, rotation = 90, size = 15)
plt.show()

# %% [markdown]
# ## Introduce selection to your function from Part 1 (as an additional parameter that can be specified) and plot the allele frequency trajectory for some chosen parameters. On your plot, make sure you note what your selection coefficient for the simulation was

# %%
def generationtester_selection(p, population, selection):
    i = 1
    list = [p]
    time = [1]
    s = p
    while True:
        s = np.random.binomial(2*population, ((s*2*population)*(1+selection))/(2*population - s*2*population + s*2*population*(1+selection)))/(2*population)
        list.append(s)
        time.append(i + 1)
        if s == 0 or s == 1:
            print(i)
            return time, list
            break
        else:
            i = i+1

# %%
output_m = generationtester_selection(0.5, 100, -0.1)
output_m2 = generationtester_selection(0.5, 100, -0.2)
output_m3 = generationtester_selection(0.5, 100, -0.3)
output_m4 = generationtester_selection(0.5, 100, -0.4)
output = generationtester_selection(0.5, 100, 0.1)
output_2 = generationtester_selection(0.5, 100, 0.2)
output_3 = generationtester_selection(0.5, 100, 0.3)
output_4 = generationtester_selection(0.5, 100, 0.4)
# Out:
# 40
# 20
# 19
# 9
# 90
# 24
# 18
# 12

# %%
plt.figure(figsize = (20, 20))
a = plt.scatter(output[0], output[1], c = "green", s = 15)
b = plt.scatter(output_2[0], output_2[1], c = "red", s = 15)
c = plt.scatter(output_3[0], output_3[1], c = "purple", s = 15)
d = plt.scatter(output_4[0], output_4[1], c = "blue", s = 15)
e = plt.scatter(output_m[0], output_m[1], c = "cyan", s = 15)
f = plt.scatter(output_m2[0], output_m2[1], c = "brown", s = 15)
g = plt.scatter(output_m3[0], output_m3[1], c = "black", s = 15)
h = plt.scatter(output_m4[0], output_m4[1], c = "orange", s = 15)
plt.legend((a, b, c, d, e, f, g, h),
           ("selection = 0.1", "selection = 0.2", "selection = 0.3",
           "selection = 0.4","selection = -0.1", "selection = -0.2", "selection = -0.3",
           "selection = -0.4" ))
plt.xlabel("generation")
plt.ylabel("allele frequency")
plt.title("Initial frequency = 0.5, population = 100", size = 25)
plt.show()

# %%
plt.figure(figsize = (20, 20))
a = plt.plot(output[0], output[1], marker = 'o', c = "green")
b = plt.plot(output_2[0], output_2[1], marker = 'o', c = "red")
c = plt.plot(output_3[0], output_3[1], marker = 'o', c = "purple")
d = plt.plot(output_4[0], output_4[1], marker = 'o', c = "blue")
e = plt.plot(output_m[0], output_m[1], marker = 'o', c = "cyan")
f = plt.plot(output_m2[0], output_m2[1], marker = 'o', c = "brown")
g = plt.plot(output_m3[0], output_m3[1], marker = 'o', c = "black")
h = plt.plot(output_m4[0], output_m4[1], marker = 'o', c = "orange")
plt.legend(("selection = 0.1", "selection = 0.2", "selection = 0.3",
           "selection = 0.4","selection = -0.1", "selection = -0.2", "selection = -0.3",
           "selection = -0.4" ))
plt.xlabel("generation")
plt.ylabel("allele frequency")
plt.title("Initial frequency = 0.5, population = 100", size = 25)
plt.show()
